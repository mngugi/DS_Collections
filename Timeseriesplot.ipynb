# %% [markdown]
# <a href="https://colab.research.google.com/github/mngugi/DS_Collections/blob/main/Timeseriesplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

sns.set_theme( style ="whitegrid")


fmri= sns.load_dataset("fmri")

sns.lineplot(x="timepoint", y = "signal",
             data=fmri, hue="region", style="event")
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>
