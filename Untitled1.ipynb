# %%
# %run Drone_flyTest.py
# Out:
# Response: Connected
# Published RC control data: {'left_right': None, 'forward_backward': None, 'up_down': None, 'yaw': None, 'cameraangle': None, 'streamon': True, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 25, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Published RC control data: {'left_right': 0, 'forward_backward': 0, 'up_down': 0, 'yaw': 0, 'cameraangle': 0, 'streamon': None, 'color': {'red': None, 'green': None, 'blue': None}}
# Drone has taken off.
# Failed to decode frame.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/Documents/GitHub/DS_Collections/Drone_flyTest.py:62
#      58 camera_angle = 0
#      60 # Check for key presses and update speeds
# ---> 62 if keyboard.is_pressed('w'):  # Move forward
# ...
